# %% [markdown]
# <h3>문제 설명</h3>
# <p>피보나치 수는 F(0) = 0, F(1) = 1일 때, 1 이상의 n에 대하여 <code>F(n) = F(n-1) + F(n-2)</code> 가 적용되는 수 입니다.</p>
# <p>예를 들어,</p>
# <ul>
#   <li>F(2) = F(0) + F(1) = 0 + 1 = 1</li>
#   <li>F(3) = F(1) + F(2) = 1 + 1 = 2</li>
#   <li>F(4) = F(2) + F(3) = 1 + 2 = 3</li>
# </ul>
# <p>2 이상의 n이 입력되었을 때, n번째 피보나치 수를 반환하는 함수, <code>solution</code>을 완성해 주세요.</p>
# <h3>제한 조건</h3>
# <ul>
#   <li>n은 2 이상 50 이하의 자연수입니다.</li>
# </ul>

# %%
def solution(n):
    # 코드를 작성해주세요
    return 0

# %%
assert solution(2) == 1
assert solution(3) == 2
assert solution(5) == 5
assert solution(10) == 55
assert solution(20) == 6765
