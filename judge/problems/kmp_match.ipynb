# %% [markdown]
# <h3>문제 설명</h3>
# <p>텍스트 <code>txt</code>와 검색할 패턴 <code>pat</code>이 주어졌을 때, <strong>KMP법(Knuth-Morris-Pratt Method)</strong>을 사용하여 <code>pat</code>이 <code>txt</code> 내에서 처음 등장하는 인덱스를 반환하는 함수 <code>solution(txt, pat)</code>을 작성하세요.</p>
# <ul>
#   <li>검색에 성공하면 패턴의 첫 글자가 위치한 텍스트의 인덱스(0-based)를 반환합니다.</li>
#   <li>검색에 실패하면 <code>-1</code>을 반환합니다.</li>
#   <li>패턴 중복 분석을 통해 <code>skip 배열</code>을 먼저 구축한 후 검색을 수행해야 합니다.</li>
# </ul>
# <h3>제한 조건</h3>
# <ul>
#   <li>문자열 <code>txt</code>와 <code>pat</code>의 길이는 100,000 이하의 자연수입니다.</li>
#   <li>대소문자를 구분합니다.</li>
# </ul>

# %%
def solution(txt, pat):
    # KMP법 코드를 완성하세요
    if not pat: return 0
    
    # 1단계: skip 배열 만들기
    
    # 2단계: 검색하기
    
    return -1

# %%
assert solution("ZABCABXABCABD", "ABCABD") == 7
assert solution("ABABCDEFGHA", "ABC") == 2
assert solution("HELLO WORLD", "WORLD") == 6
assert solution("AAAAAAAAB", "AAAB") == 5
assert solution("PYTHON", "XYZ") == -1
