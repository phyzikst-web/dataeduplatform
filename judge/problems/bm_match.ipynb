# %% [markdown]
# <h3>문제 설명</h3>
# <p>텍스트 <code>txt</code>와 검색할 패턴 <code>pat</code>이 주어졌을 때, <strong>보이어·무어법(Boyer-Moore Method)</strong>을 사용하여 <code>pat</code>이 <code>txt</code> 내에서 처음 등장하는 인덱스를 반환하는 함수 <code>solution(txt, pat)</code>을 작성하세요.</p>
# <ul>
#   <li>검색에 성공하면 패턴의 첫 글자가 위치한 텍스트의 인덱스(0-based)를 반환합니다.</li>
#   <li>검색에 실패하면 <code>-1</code>을 반환합니다.</li>
#   <li>ASCII 문자셋(0~255)을 지원하는 크기 256의 <code>skip 배열</code>을 만든 뒤, 패턴의 오른쪽 끝부터 역방향 비교를 수행해야 합니다.</li>
# </ul>
# <h3>제한 조건</h3>
# <ul>
#   <li>문자열 <code>txt</code>와 <code>pat</code>의 길이는 100,000 이하의 자연수입니다.</li>
#   <li>대소문자를 구분하며, 영문/공백/숫자/기호 등의 ASCII 문자만 입력으로 주어집니다.</li>
# </ul>

# %%
def solution(txt, pat):
    # 보이어·무어법 코드를 완성하세요
    if not pat: return 0
    
    # 1단계: ASCII 256 크기의 skip 배열 만들기
    
    # 2단계: 역방향 비교 및 탐색
    
    return -1

# %%
assert solution("ABABCDEFGHA", "ABC") == 2
assert solution("ZABCABXABCABD", "ABCABD") == 7
assert solution("HELLO WORLD", "WORLD") == 6
assert solution("AAAAAAAAB", "AAAB") == 5
assert solution("PYTHON", "XYZ") == -1
